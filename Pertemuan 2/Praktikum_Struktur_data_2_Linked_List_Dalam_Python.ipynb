# %% [markdown]
# Membuat node linked list

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

print(n1.dataval)
print(n2.dataval)
print(n3.dataval)
# Out:
# Januari
# Februari
# Maret

# %% [markdown]
# Membuat class linked list

# %%
class LinkedList:
    def __init__(self):
        self.headval = None

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-735/4270012417.py in <cell line: 0>()
#       4
#       5 Li = LinkedList()
# ----> 6 Li.headval = n1
#       7
#       8 # Link first Node to second node
#
# NameError: name 'n1' is not defined

# %% [markdown]
# Menelusuri Node dalam Linked List

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

Li = LinkedList()
Li.headval = n1

# Link first Node to second node
Li.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

Li.listprint()
# Out:
# Januari
# Februari
# Maret

# %% [markdown]
# Penyisipan di awal node pada linked list

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class LinkedList:
    def __init__(self):
        self.headval = None

    # Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # create atribut add begining to Update the new nodes next val to existing node
    def AddBegining(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

L1 = LinkedList()
L1.headval = n1

# Link first Node to second node
L1.headval.nextval = n2

# Link second Node to third node
n2.nextval = n3

L1.AddBegining("Start")
L1.listprint()
# Out:
# Start
# Januari
# Februari
# Maret

# %% [markdown]
# Penyisipan di tengah

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")

class LinkedList:
    def __init__(self):
        self.headval = None

    # Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Function to add node in the middle
    def AddInbetween(self, mid_node, newdata):
        if mid_node is None:
            print("The mentioned node is absent")
            return

        NewNode = Node(newdata)
        NewNode.nextval = mid_node.nextval
        mid_node.nextval = NewNode

L1 = LinkedList()
L1.headval = n1

# Link first Node to second node
L1.headval.nextval = n2

# add node after n1
L1.AddInbetween(n1, "Middle")
L1.listprint()
# Out:
# Januari
# Middle
# Februari

# %% [markdown]
# Penyisipan di akhir

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

# create node
n1 = Node("Januari")
n2 = Node("Februari")

class LinkedList:
    def __init__(self):
        self.headval = None

    # Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Function to add newnode in the end
    def AddInEnd(self, newdata):
        NewNode = Node(newdata)
        if self.headval is None:
            self.headval = NewNode
            return

        last = self.headval
        while(last.nextval):
            last = last.nextval

        last.nextval = NewNode

L1 = LinkedList()
L1.headval = n1

# Link first Node to second node
L1.headval.nextval = n2

# add node in the end
L1.AddInEnd("The Last")
L1.listprint()
# Out:
# Januari
# Februari
# The Last

# %% [markdown]
# Menghapus node pada linked list dengan kata kunci

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None


class LinkedList:
    def __init__(self):
        self.headval = None

    # Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Function to add node in the beginning
    def AddBeginning(self, newdata):
        NewNode = Node(newdata)

        # Update the new node's next value to existing node
        NewNode.nextval = self.headval
        self.headval = NewNode

    # Function to remove node by key
    def RemoveNode(self, Removekey):
        HeadVal = self.headval

        if (HeadVal is not None):
            if (HeadVal.dataval == Removekey):
                self.headval = HeadVal.nextval
                HeadVal = None
                return

        while (HeadVal is not None):
            if HeadVal.dataval == Removekey:
                break
            prev = HeadVal
            HeadVal = HeadVal.nextval

        if (HeadVal == None):
            return

        prev.nextval = HeadVal.nextval
        HeadVal = None


# create linked list named Li
Li = LinkedList()

# add node
Li.AddBeginning("April")
Li.AddBeginning("Maret")
Li.AddBeginning("Febuari")

print("Sebelum dilakukan remove")
Li.listprint()

print("-----------------------------------------")

# remove node by key = "Maret"
Li.RemoveNode("Maret")

print("Setelah dilakukan remove dengan kunci 'Maret'")
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Febuari
# Maret
# April
# -----------------------------------------
# Setelah dilakukan remove dengan kunci 'Maret'
# Febuari
# April

# %% [markdown]
# Hapus node di awal

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None


class LinkedList:
    def __init__(self):
        self.headval = None

    # Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Function to add node in the beginning
    def AddBeginning(self, newdata):
        NewNode = Node(newdata)

        # Update the new node's next value to existing node
        NewNode.nextval = self.headval
        self.headval = NewNode

    # Function to remove first node
    def RemoveFirst(self):
        if self.headval is not None:
            afterhead = self.headval
            self.headval = afterhead.nextval
            afterhead = None


# create linked list named Li
Li = LinkedList()

# add node
Li.AddBeginning("April")
Li.AddBeginning("Maret")
Li.AddBeginning("Febuari")

print("Sebelum dilakukan remove")
Li.listprint()

print("-----------------------------------------")

# remove first node
Li.RemoveFirst()

print("Setelah dilakukan remove node pertama")
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Febuari
# Maret
# April
# -----------------------------------------
# Setelah dilakukan remove node pertama
# Maret
# April

# %% [markdown]
# Hapus node di akhir

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None


class LinkedList:
    def __init__(self):
        self.headval = None

    # Print the linked list
    def listprint(self):
        printval = self.headval
        while printval is not None:
            print(printval.dataval)
            printval = printval.nextval

    # Function to add new node in the end
    def AddInEnd(self, newdata):
        NewNode = Node(newdata)

        if self.headval is None:
            self.headval = NewNode
            return

        last = self.headval
        while (last.nextval):
            last = last.nextval

        last.nextval = NewNode

    # Function to remove last node
    def RemoveEnd(self):
        last = self.headval

        while (last is not None):
            if last.nextval == None:
                break
            prev = last
            last = last.nextval

        if (last == None):
            return

        prev.nextval = last.nextval
        last = None


# create linked list named Li
Li = LinkedList()

# add node
Li.AddInEnd("Januari")
Li.AddInEnd("Februari")
Li.AddInEnd("Maret")

print("Sebelum dilakukan remove")
Li.listprint()

print("-----------------------------------------")

# remove last node
Li.RemoveEnd()

print("Setelah dilakukan remove node terakhir")
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Januari
# Februari
# Maret
# -----------------------------------------
# Setelah dilakukan remove node terakhir
# Januari
# Februari

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None

# bikin node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

# bikin linked list
Li = LinkedList()
Li.headval = n1

# sambungin
Li.headval.nextval = n2
n2.nextval = n3

# tampilkan
print(Li.headval.dataval)
print(Li.headval.nextval.dataval)
print(Li.headval.nextval.nextval.dataval)
# Out:
# Januari
# Februari
# Maret

# %%
class Node:
    def __init__(self, dataval=None):
        self.dataval = dataval
        self.nextval = None


class LinkedList:
    def __init__(self):
        self.headval = None

    def AddBeginning(self, newdata):
        NewNode = Node(newdata)
        NewNode.nextval = self.headval
        self.headval = NewNode

    def RemoveNode(self, key):
        curr = self.headval
        prev = None

        while curr and curr.dataval != key:
            prev = curr
            curr = curr.nextval

        if not curr:
            return

        if not prev:
            self.headval = curr.nextval
        else:
            prev.nextval = curr.nextval

    def listprint(self):
        temp = self.headval
        while temp:
            print(temp.dataval)
            temp = temp.nextval


Li = LinkedList()

Li.AddBeginning("April")
Li.AddBeginning("Maret")
Li.AddBeginning("Februari")

print("Sebelum remove:")
Li.listprint()

Li.RemoveNode("Maret")

print("Setelah remove Maret:")
Li.listprint()
# Out:
# Sebelum remove:
# Februari
# Maret
# April
# Setelah remove Maret:
# Februari
# April

# %% [markdown]
# Latihan 2

# %% [markdown]
# Buatlah double linked list dengan 3 node didalamnya

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

# bikin node hero
n1 = Node("Alucard")
n2 = Node("Miya")
n3 = Node("Tigreal")

# sambung maju
n1.next = n2
n2.next = n3

# sambung mundur
n2.prev = n1
n3.prev = n2

# tampil maju
print("Maju:")
temp = n1
while temp:
    print(temp.data, end=" <-> ")
    temp = temp.next
print("None")

# tampil mundur
print("Mundur:")
temp = n3
while temp:
    print(temp.data, end=" <-> ")
    temp = temp.prev
print("None")
# Out:
# Maju:
# Alucard <-> Miya <-> Tigreal <-> None
# Mundur:
# Tigreal <-> Miya <-> Alucard <-> None

# %% [markdown]
# kemudian lakukan penyisipan di tengah

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

# bikin node hero
n1 = Node("Alucard")
n2 = Node("Miya")
n3 = Node("Tigreal")

# sambung awal
n1.next = n2
n2.prev = n1
n2.next = n3
n3.prev = n2

# ===== sisip tengah =====
newHero = Node("Gusion")

newHero.next = n2
newHero.prev = n1
n1.next = newHero
n2.prev = newHero
# ========================

# tampil maju
temp = n1
while temp:
    print(temp.data, end=" <-> ")
    temp = temp.next
print("None")
# Out:
# Alucard <-> Gusion <-> Miya <-> Tigreal <-> None

# %% [markdown]
# lalu hapus dengan kata kunci !

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None


def removeNode(head, key):
    temp = head

    while temp and temp.data != key:
        temp = temp.next

    if not temp:
        return head

    if temp.prev:
        temp.prev.next = temp.next
    else:
        head = temp.next

    if temp.next:
        temp.next.prev = temp.prev

    return head


# bikin node hero
n1 = Node("Alucard")
n2 = Node("Miya")
n3 = Node("Tigreal")

# sambung awal
n1.next = n2
n2.prev = n1
n2.next = n3
n3.prev = n2

# sisip tengah
newHero = Node("Gusion")
newHero.next = n2
newHero.prev = n1
n1.next = newHero
n2.prev = newHero

print("Sebelum hapus:")
temp = n1
while temp:
    print(temp.data, end=" <-> ")
    temp = temp.next
print("None")

# hapus Gusion
n1 = removeNode(n1, "Gusion")

print("\nSetelah hapus Gusion:")
temp = n1
while temp:
    print(temp.data, end=" <-> ")
    temp = temp.next
print("None")
# Out:
# Sebelum hapus:
# Alucard <-> Gusion <-> Miya <-> Tigreal <-> None
#
# Setelah hapus Gusion:
# Alucard <-> Miya <-> Tigreal <-> None

# %% [markdown]
# Buatlah circular linked list dengan 3 node didalamnya, kemudian lakukan penyisipan akhir dan hapus akhir !

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class CircularLinkedList:
    def __init__(self):
        self.head = None

    def addEnd(self, data):
        newNode = Node(data)

        if not self.head:
            self.head = newNode
            newNode.next = self.head
            return

        temp = self.head
        while temp.next != self.head:
            temp = temp.next

        temp.next = newNode
        newNode.next = self.head

    def removeEnd(self):
        if not self.head:
            return

        if self.head.next == self.head:
            self.head = None
            return

        temp = self.head
        while temp.next.next != self.head:
            temp = temp.next

        temp.next = self.head

    def printList(self):
        if not self.head:
            return

        temp = self.head
        while True:
            print(temp.data, end=" -> ")
            temp = temp.next
            if temp == self.head:
                break
        print("(balik ke awal)")


cl = CircularLinkedList()

# 3 node awal
cl.addEnd("Alok")
cl.addEnd("Kelly")
cl.addEnd("Hayato")

print("Awal:")
cl.printList()

# tambah akhir
cl.addEnd("Chrono")
print("Setelah tambah akhir:")
cl.printList()

# hapus akhir
cl.removeEnd()
print("Setelah hapus akhir:")
cl.printList()
# Out:
# Awal:
# Alok -> Kelly -> Hayato -> (balik ke awal)
# Setelah tambah akhir:
# Alok -> Kelly -> Hayato -> Chrono -> (balik ke awal)
# Setelah hapus akhir:
# Alok -> Kelly -> Hayato -> (balik ke awal)
