# %% [markdown]
# Contoh Graph

# %%
graph = {
    "A": ["B", "C"],
    "B": ["A", "C"],
    "C": ["A", "B"]
}

print(graph)
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'C'], 'C': ['A', 'B']}

# %%
# Contoh graph sederhana menggunakan dictionary

graph = {
    "A": ["B", "C"],
    "B": ["A", "D"],
    "C": ["A"],
    "D": ["B"]
}

print(graph)
# Out:
# {'A': ['B', 'C'], 'B': ['A', 'D'], 'C': ['A'], 'D': ['B']}

# %% [markdown]
# Representasi Graph dengan Adjacency List

# %%
# Membuat graf tak berarah menggunakan adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

# Menampilkan graf
def print_graph(graf):
    for node in graf:
        print(f"{node} -> {graf[node]}")

print_graph(graph)
# Out:
# A -> ['B', 'C']
# B -> ['A', 'D', 'E']
# C -> ['A', 'F']
# D -> ['B']
# E -> ['B', 'F']
# F -> ['C', 'E']

# %% [markdown]
# Traversal Graph menggunakan BFS

# %%
from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    while queue:
        vertex = queue.popleft()

        if vertex not in visited:
            print(vertex, end=" ")
            visited.add(vertex)

            queue.extend(
                [neighbor for neighbor in graph[vertex]
                 if neighbor not in visited]
            )

# Contoh pemanggilan
bfs(graph, 'A')
# Out:
# A B C D E F

# %% [markdown]
# Traversal Graf menggunakan DFS

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()

    if start not in visited:
        print(start, end=" ")
        visited.add(start)

        for neighbor in graph[start]:
            dfs(graph, neighbor, visited)

# Contoh pemanggilan
dfs(graph, 'A')
# Out:
# A B D E F C

# %% [markdown]
# Latihan

# %%
graph = {
    'London': ['Manchester', 'Liverpool'],
    'Manchester': ['London', 'Birmingham', 'Leeds'],
    'Liverpool': ['London', 'Bristol'],
    'Birmingham': ['Manchester'],
    'Leeds': ['Manchester', 'Bristol'],
    'Bristol': ['Liverpool', 'Leeds']
}

def print_graph(g):
    for node in g:
        print(f"{node} -> {', '.join(g[node])}")

def dfs(graph, start, visited=None):
    if visited is None:
        visited = []

    visited.append(start)

    for neighbor in graph[start]:
        if neighbor not in visited:
            dfs(graph, neighbor, visited)

    return visited

from collections import deque

def bfs(graph, start):
    visited = []
    queue = deque([start])

    while queue:
        node = queue.popleft()

        if node not in visited:
            visited.append(node)

            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append(neighbor)

    return visited

def find_path(graph, start, end, path=None, visited=None):
    if path is None:
        path = []

    if visited is None:
        visited = set()

    path.append(start)
    visited.add(start)

    if start == end:
        return path

    for neighbor in graph[start]:
        if neighbor not in visited:
            result = find_path(graph, neighbor, end, path.copy(), visited)

            if result:
                return result

    return None

def is_connected(graph):
    start = next(iter(graph))
    visited = dfs(graph, start)

    return len(visited) == len(graph)


print("GRAPH:")
print_graph(graph)

print("\nDFS dari London:", dfs(graph, 'London'))
print("BFS dari London:", bfs(graph, 'London'))

print("\nJalur dari London ke Bristol:", find_path(graph, 'London', 'Bristol'))

print("\nApakah graph terhubung?", is_connected(graph))
# Out:
# GRAPH:
# London -> Manchester, Liverpool
# Manchester -> London, Birmingham, Leeds
# Liverpool -> London, Bristol
# Birmingham -> Manchester
# Leeds -> Manchester, Bristol
# Bristol -> Liverpool, Leeds
#
# DFS dari London: ['London', 'Manchester', 'Birmingham', 'Leeds', 'Bristol', 'Liverpool']
# BFS dari London: ['London', 'Manchester', 'Liverpool', 'Birmingham', 'Leeds', 'Bristol']
#
# Jalur dari London ke Bristol: ['London', 'Manchester', 'Leeds', 'Bristol']
#
# Apakah graph terhubung? True
